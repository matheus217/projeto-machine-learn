# %% [markdown]
# <a href="https://colab.research.google.com/github/matheus217/projeto-machine-learn/blob/master/KinectOrganizationDATA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
import os
import tarfile
from six.moves import urllib

FILE_TO_DOWNLOAD =  "horizontalarm.csv"
DOWNLOAD_ROOT = "https://raw.githubusercontent.com/matheus217/projeto-machine-learn/master/"
DATA_PATH = "kinect/"
DATA_URL = DOWNLOAD_ROOT + DATA_PATH + FILE_TO_DOWNLOAD

def fetch_data(data_url=DATA_URL, data_path=DATA_PATH, file_to_download=FILE_TO_DOWNLOAD):
  if not os.path.isdir(data_path):
    os.makedirs(data_path)
  urllib.request.urlretrieve(data_url, data_path+file_to_download)
  
  
fetch_data()

# observando se o diretório datasets foi criado com sucesso 
# !ls kinect
# Out:
# horizontalarm.csv

# %%
# Importing the dataset
dataset = pd.read_csv(DATA_PATH+'horizontalarm.csv')


dataset.head(  )

#print(dataset.iloc[:,:].values)
# Out:
#           1       1.1              1.2       1.3              1.4       1.5  \
# 0  0.553138 -0.163760  2.043650.524907 -0.099541  2.092150.565528  0.269455
# 1  0.554577 -0.159980  2.046250.526018 -0.097279  2.093670.565775  0.269456
# 2  0.555894 -0.156262  2.048840.527188 -0.094709   2.095470.56599  0.269459
# 3  0.556846 -0.153846  2.050720.528159 -0.092816  2.096970.566193  0.269452
# 4  0.557528 -0.152163    2.05210.52892 -0.091403  2.098190.566381  0.269433
#
#                1.6       1.7              1.8       1.9  ...   \
# 0   2.14380.647266  0.431261  2.121190.457287  0.129052  ...
# 1   2.14350.646697  0.431193  2.119850.457343  0.129057  ...
# 2  2.143250.646232  0.431147   2.118810.45734  0.129120  ...
# 3  2.143030.645863  0.431106  2.118030.457259  0.129347  ...
# 4  2.142880.645568  0.431071  2.117430.457121  0.129677  ...
#
#               1.32      1.33             1.34      1.35             1.36  \
# ...

# %%
for i in range(0, 10):
    for j in range(0, 5):
# Out:
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
# oi
